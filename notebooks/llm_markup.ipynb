# %%
import openai
import pandas as pd
from tqdm import tqdm
from pulemet import Pulemet
import asyncio

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
client = openai.AsyncOpenAI(
    base_url="https://api.llm7.io/v1",
    api_key="unused"
)
pulemet = Pulemet(rps = 2, pbar=tqdm)
# Out:
# Total: 0it [00:00, ?it/s]

# %%
df = pd.read_csv('worldcities.csv')
df['description'] = ['']*len(df)
df.head(5)
# Out:
#         city city_ascii      lat       lng    country iso2 iso3   admin_name  \
# 0      Tokyo      Tokyo  35.6870  139.7495      Japan   JP  JPN        Tōkyō
# 1    Jakarta    Jakarta  -6.1750  106.8275  Indonesia   ID  IDN      Jakarta
# 2      Delhi      Delhi  28.6100   77.2300      India   IN  IND        Delhi
# 3  Guangzhou  Guangzhou  23.1300  113.2600      China   CN  CHN    Guangdong
# 4     Mumbai     Mumbai  19.0761   72.8775      India   IN  IND  Mahārāshtra
#
#    capital  population          id description
# 0  primary  37785000.0  1392685764
# 1  primary  33756000.0  1360771077
# 2    admin  32226000.0  1356872604
# 3    admin  26940000.0  1156237133
# 4    admin  24973000.0  1356226629

# %%
async def ask_gpt(client, data, model = "gpt-4.1"):
    try:
        city_list = "; ".join([f"{name}, {latitude}, {longitude}" for name, latitude, longitude in data])
        response = await client.chat.completions.create(
            model=model,
            messages=[
                {"role": "system", "content": f"You are creating riddles. If you get the name of city/town/village, you try to describe it without naming it or its coordinates. \
                    You usually use a description of the appearance of a city, famous facts about it, or the nearest iconic places. Never name the city/town/village.\
                    Use hints that distinguish the place described from other similar places in the world. Your description contains only a couple sentences. Use only english language in answer." },
                {"role": "user", "content": f"You will get a list of names,latitude,longitude of {len(list(data))} cities/towns/villages in <list> tokens, you should answer to them separately, separate them by <answer> token. <list>{city_list}<list>"}
            ]
        )
        return response.choices[0].message.content
    except Exception as e:
        return f"Ошибка: {str(e)}"

# %%
batch = 10
tasks = pulemet.process([ask_gpt(client, zip(df[i:i+batch]['city_ascii'].values, df[i:i+batch]['lat'].values, df[i:i+batch]['lng'].values)) for i in range(0, len(df), batch)])
responses = await asyncio.gather(*tasks, return_exceptions=True)
# Out:
# Total: 100%|██████████| 4806/4806 [42:12<00:00,  2.00it/s]

# %%
failed = []
responses_fixed = []
for i in range(0, len(df), batch):
    if len(('<answer>'+responses[i//batch]+'<answer>').replace('\n', '').replace('<answer><answer>', '<answer>').replace('<answer><answer>', '<answer>').split('<answer>')[1:-1]) != batch:
        responses_fixed.extend(['']*min(batch, len(df)-i))
        failed.append(i)
    else:
        responses_fixed.extend(('<answer>'+responses[i//batch]+'<answer>').replace('\n', '').replace('<answer><answer>', '<answer>').replace('<answer><answer>', '<answer>').split('<answer>')[1:-1])
failed
# Out:
# [3160,
#  5300,
#  6650,
#  8200,
#  8570,
#  17110,
#  17940,
#  19140,
#  20460,
#  20480,
#  20580,
#  20610,
#  29500,
#  31340,
#  31420,
#  31430,
#  31440,
#  35040,
#  35220,
#  39840,
#  42740,
#  47030,
#  48050]

# %%
df['description']= responses_fixed
df[df['description']!=''].to_csv('data/gpt41_markup.csv')
df.head(20)
# Out:
#             city    city_ascii      lat       lng        country iso2 iso3  \
# 0          Tokyo         Tokyo  35.6870  139.7495          Japan   JP  JPN
# 1        Jakarta       Jakarta  -6.1750  106.8275      Indonesia   ID  IDN
# 2          Delhi         Delhi  28.6100   77.2300          India   IN  IND
# 3      Guangzhou     Guangzhou  23.1300  113.2600          China   CN  CHN
# 4         Mumbai        Mumbai  19.0761   72.8775          India   IN  IND
# 5         Manila        Manila  14.5958  120.9772    Philippines   PH  PHL
# 6       Shanghai      Shanghai  31.2286  121.4747          China   CN  CHN
# 7      São Paulo     Sao Paulo -23.5504  -46.6339         Brazil   BR  BRA
# 8          Seoul         Seoul  37.5667  126.9833   Korea, South   KR  KOR
# 9    Mexico City   Mexico City  19.4333  -99.1333         Mexico   MX  MEX
# 10       Kolkāta       Kolkata  22.5675   88.3700          India   IN  IND
# 11         Cairo         Cairo  30.0444   31.2358          Egypt   EG  EGY
# 12       Karachi       Karachi  24.8600   67.0100       Pakistan   PK  PAK
# 13         Dhaka         Dhaka  23.7289   90.3944     Bangladesh   BD  BGD
# 14      New York      New York  40.6943  -73.9249  United States   US  USA
# 15       Beijing       Beijing  39.9067  116.3975          China   CN  CHN
# 16       Bangkok       Bangkok  13.7525  100.4942       Thailand   TH  THA
# 17      Shenzhen      Shenzhen  22.5415  114.0596          China   CN  CHN
# 18        Moscow        Moscow  55.7506   37.6175         Russia   RU  RUS
# 19  Buenos Aires  Buenos Aires -34.6036  -58.3814      Argentina   AR  ARG
#
#                           admin_name  capital  population          id  \
# 0                              Tōkyō  primary  37785000.0  1392685764
# 1                            Jakarta  primary  33756000.0  1360771077
# 2                              Delhi    admin  32226000.0  1356872604
# 3                          Guangdong    admin  26940000.0  1156237133
# 4                        Mahārāshtra    admin  24973000.0  1356226629
# 5                             Manila  primary  24922000.0  1608618140
# 6                           Shanghai    admin  24073000.0  1156073548
# 7                          São Paulo    admin  23086000.0  1076532519
# 8                              Seoul  primary  23016000.0  1410836482
# 9                   Ciudad de México  primary  21804000.0  1484247881
# 10                       West Bengal    admin  21747000.0  1356060520
# 11                        Al Qāhirah  primary  20296000.0  1818253931
# 12                             Sindh    admin  20249000.0  1586129469
# 13                             Dhaka  primary  19134000.0  1050529279
# 14                          New York      NaN  18832416.0  1840034016
# 15                           Beijing  primary  18522000.0  1156228865
# 16            Krung Thep Maha Nakhon  primary  18007000.0  1764068610
# 17                         Guangdong    minor  17619000.0  1156158707
# 18                            Moskva  primary  17332000.0  1643318494
# 19  Buenos Aires, Ciudad Autónoma de  primary  16710000.0  1032717330
#
#                                           description
# 0   This metropolis is renowned for its bright neo...
# 1   This city sits on an archipelago, is known for...
# 2   This urban giant houses centuries-old forts an...
# 3   This city lies along the Pearl River, is celeb...
# 4   This coastal megacity is recognized by its col...
# 5   This is a densely populated capital on a bay, ...
# 6   This city is recognized by its towering Orient...
# 7   This sprawling urban center is Brazil’s econom...
# 8   This place is famous for its K-pop stars, perf...
# 9   This high-altitude city was built on an ancien...
# 10  This vibrant metropolis on the eastern banks o...
# 11  A sprawling city on the banks of the Nile, ren...
# 12  Located on the Arabian Sea, this port city in ...
# 13  This densely populated South Asian capital is ...
# 14  Famous for its towering skyscrapers, this nort...
# 15  A city in northern China known for a massive s...
# 16  Known for ornate golden temples and effervesce...
# 17  This ultramodern city in southern China rose f...
# 18  This grand city stretches alongside the Moskva...
# 19  This South American capital on the shores of t...

# %%
batch = 10
tasks = pulemet.process([ask_gpt(client, zip(df[i:i+batch]['city_ascii'].values, df[i:i+batch]['lat'].values, df[i:i+batch]['lng'].values), model='grok') for i in range(0, len(df), batch)])
responses_grok = await asyncio.gather(*tasks, return_exceptions=True)
# Out:
# Total: 100%|██████████| 4806/4806 [53:12<00:00,  1.97it/s]

# %%
failed = []
responses_fixed_grok = []
for i in range(0, len(df), batch):
    if len(('<answer>'+responses_grok[i//batch]+'<answer>').replace('\n', '').replace('<answer><answer>', '<answer>').replace('<answer><answer>', '<answer>').split('<answer>')[1:-1]) != batch:
        responses_fixed_grok.extend(['']*min(batch, len(df)-i))
        failed.append(i)
    else:
        responses_fixed_grok.extend(('<answer>'+responses_grok[i//batch]+'<answer>').replace('\n', '').replace('<answer><answer>', '<answer>').replace('<answer><answer>', '<answer>').split('<answer>')[1:-1])
failed
# Out:
# [70,
#  210,
#  640,
#  1580,
#  2010,
#  2530,
#  2650,
#  2830,
#  2910,
#  2930,
#  3130,
#  3140,
#  3170,
#  4090,
#  4140,
#  4150,
#  4310,
#  4400,
#  4680,
#  4880,
#  4940,
#  5220,
#  5400,
#  5700,
#  5910,
#  5920,
#  5930,
#  6290,
#  6470,
#  6940,
#  7210,
#  7240,
#  7370,
#  7490,
#  7910,
#  9110,
#  9500,
#  9590,
#  9890,
#  9940,
#  10090,
#  10730,
#  10880,
#  10910,
#  11050,
#  11410,
#  11620,
#  12340,
#  12430,
#  12580,
#  12730,
#  12970,
#  13750,
#  14700,
#  14880,
#  15360,
#  15840,
#  16220,
#  16560,
#  16930,
#  16940,
#  17460,
#  17780,
#  17820,
#  18100,
#  18260,
#  18500,
#  18820,
#  19120,
#  19130,
#  19330,
#  20290,
#  20850,
#  21260,
#  21350,
#  22100,
#  23260,
#  23320,
#  23630,
#  24180,
#  24400,
#  25070,
#  26080,
#  26110,
#  27310,
#  27390,
#  27620,
#  27760,
#  27770,
#  27890,
#  27940,
#  28730,
#  28960,
#  29070,
#  29250,
#  29390,
#  29760,
#  30920,
#  31720,
#  31730,
#  32450,
#  32510,
#  32750,
#  33210,
#  33450,
#  33890,
#  34060,
#  34600,
#  34890,
#  34960,
#  35120,
#  35250,
#  35670,
#  35900,
#  36100,
#  37200,
#  37340,
#  37990,
#  38000,
#  38380,
#  38750,
#  38990,
#  39270,
#  39980,
#  40140,
#  40450,
#  41260,
#  41300,
#  41770,
#  41920,
#  42060,
#  42130,
#  42970,
#  43030,
#  44330,
#  44450,
#  44550,
#  44580,
#  44830,
#  45190,
#  45270,
#  45280,
#  45750,
#  46430,
#  46800,
#  47170,
#  47240,
#  47310,
#  48050]

# %%
df['description_grok']= responses_fixed_grok
df[df['description_grok']!=''].drop(['description'], axis=1).rename({'description_grok':'description'}, axis=1).to_csv('data/grok_markup.csv')

# %%
async def top5_landmarks(client, data, model = "gpt-4.1"):
    try:
        city_list = "; ".join([f"{name}, {latitude}, {longitude}" for name, latitude, longitude in data])
        response = await client.chat.completions.create(
            model=model,
            messages=[
                {"role": "system", "content": f"You are a tour guide and your task is to advise the most famous and interesting places of the settlement. Don't name coordinates of this places. \
                    You can name this landmarks or describe it in couple words. Don't name settlement in description. You should give exactly a five landmarks for each settlement.\
                    Try to make these sights show the uniqueness of the settlement together. Use only english language in answer.\
                    Answer format: <answer><landmark>Name of landmark of 1st city<text>Description of landmark of 1st city<landmark>Next name of landmark of 1st city<text>Description of that landmark of 1st city<landmark><answer><landmark>Name of landmark of 2nd city<text>Description of landmark of 2nd city<landmark>Next name of landmark of 2nd city<text>Description of that landmark of 2nd city<landmark><answer>" },
                {"role": "user", "content": f"You will get a list of names,latitude,longitude of {len(list(data))} cities/towns/villages in <list> tokens. You should answer to them separately. <list>{city_list}<list>"}
            ]
        )
        return response.choices[0].message.content
    except Exception as e:
        return f"Ошибка: {str(e)}"

# %%
batch = 10
tasks = pulemet.process([top5_landmarks(client, zip(df[i:i+batch]['city_ascii'].values, df[i:i+batch]['lat'].values, df[i:i+batch]['lng'].values)) for i in range(0, len(df), batch)])
responses_landmarks = await asyncio.gather(*tasks, return_exceptions=True)
# Out:
# Total: 100%|██████████| 9621/9621 [3:23:04<00:00,  1.47it/s]

# %%
failed = []
df_name_landmarks = []
df_description_landmarks = []
for i in range(0, len(df), batch):
    cities = ('<answer>'+responses_landmarks[i//batch]+'<answer>').replace('\n', '').replace('<answer><answer>', '<answer>').replace('<answer><answer>', '<answer>').split('<answer>')[1:-1]
    if len(cities) != batch:
        failed.append(i)
    else:
        for j, city in enumerate(cities):
            landmarks = ('<landmark>'+city+'<landmark>').replace('<landmark><landmark>', '<landmark>').replace('<landmark><landmark>', '<landmark>').split('<landmark>')[1:-1]
            if len(landmarks) != 5:
                print(i, j, 'Error landmarks')
            else:
                for k, landmark in enumerate(landmarks):
                    try:
                        place, description = landmark.split('<text>')
                        df_name_landmarks.append(dict(list(df.iloc[i+j].drop(['description','description_grok']).to_dict().items()) + list({'description':place}.items())))
                        df_description_landmarks.append(dict(list(df.iloc[i+j].drop(['description','description_grok']).to_dict().items()) + list({'description':description}.items())))
                    except:
                        print(i,j,k, 'no description')
failed
# Out:
# 270 4 Error landmarks
# 350 7 Error landmarks
# 620 7 Error landmarks
# 850 4 Error landmarks
# 1800 9 Error landmarks
# 1990 4 Error landmarks
# 4630 2 Error landmarks
# 7620 8 Error landmarks
# 9230 1 Error landmarks
# 9410 8 Error landmarks
# 9500 9 Error landmarks
# 10540 1 0 no description
# 10540 2 0 no description
# 10540 3 0 no description
# 10540 4 0 no description
# 10540 5 0 no description
# 10540 6 0 no description
# 10540 7 0 no description
# 10540 8 0 no description
# 10540 9 0 no description
# 11250 5 Error landmarks
# 11590 3 Error landmarks
# 11770 1 Error landmarks
# 13940 2 Error landmarks
# 16340 2 Error landmarks
# 16680 2 Error landmarks
# 17100 8 Error landmarks
# 17460 9 Error landmarks
# 18320 4 Error landmarks
# 19340 6 Error landmarks
# 20000 3 Error landmarks
# 21030 7 Error landmarks
# 22790 9 Error landmarks
# 24300 2 Error landmarks
# 25610 9 Error landmarks
# 26460 4 Error landmarks
# 29390 6 4 no description
# 29490 0 1 no description
# 29490 0 2 no description
# 29490 0 3 no description
# 29490 0 4 no description
# 29490 1 1 no description
# 29490 1 2 no description
# 29490 1 3 no description
# 29490 1 4 no description
# 29490 2 1 no description
# 29490 2 2 no description
# 29490 2 3 no description
# 29490 2 4 no description
# 29490 3 1 no description
# 29490 3 2 no description
# 29490 3 3 no description
# 29490 3 4 no description
# 29490 4 1 no description
# 29490 4 2 no description
# 29490 4 3 no description
# 29490 4 4 no description
# 29490 5 1 no description
# 29490 5 2 no description
# 29490 5 3 no description
# 29490 5 4 no description
# 29490 6 1 no description
# 29490 6 2 no description
# 29490 6 3 no description
# 29490 6 4 no description
# 29490 7 1 no description
# 29490 7 2 no description
# 29490 7 3 no description
# 29490 7 4 no description
# 29490 8 1 no description
# 29490 8 2 no description
# 29490 8 3 no description
# 29490 8 4 no description
# 29490 9 1 no description
# 29490 9 2 no description
# 29490 9 3 no description
# 29490 9 4 no description
# 29590 0 Error landmarks
# 29590 1 Error landmarks
# 29590 2 Error landmarks
# 29590 3 Error landmarks
# 29590 4 Error landmarks
# 29590 5 Error landmarks
# 29590 6 Error landmarks
# 29590 7 Error landmarks
# 29590 8 Error landmarks
# 29590 9 Error landmarks
# 32290 8 Error landmarks
# 32770 5 Error landmarks
# 36590 0 Error landmarks
# 36590 1 1 no description
# 36590 1 2 no description
# 36590 1 3 no description
# 36590 1 4 no description
# 36590 2 1 no description
# 36590 2 2 no description
# 36590 2 3 no description
# 36590 2 4 no description
# 36590 3 1 no description
# 36590 3 2 no description
# 36590 3 3 no description
# 36590 3 4 no description
# 36590 4 1 no description
# 36590 4 2 no description
# 36590 4 3 no description
# 36590 4 4 no description
# 36590 5 1 no description
# 36590 5 2 no description
# 36590 5 3 no description
# 36590 5 4 no description
# 36590 6 1 no description
# 36590 6 2 no description
# 36590 6 3 no description
# 36590 6 4 no description
# 36590 7 1 no description
# 36590 7 2 no description
# 36590 7 3 no description
# 36590 7 4 no description
# 36590 8 1 no description
# 36590 8 2 no description
# 36590 8 3 no description
# 36590 8 4 no description
# 36590 9 1 no description
# 36590 9 2 no description
# 36590 9 3 no description
# 36590 9 4 no description
# 42890 9 Error landmarks
# [50,
#  430,
#  3410,
#  6840,
#  8550,
#  8730,
#  10430,
#  10530,
#  10550,
#  10560,
#  10570,
#  10600,
#  10630,
#  10650,
#  10690,
#  10700,
#  11150,
#  11780,
#  13530,
#  14670,
#  16140,
#  16440,
#  19110,
#  19390,
#  22130,
#  22650,
#  22710,
#  22940,
#  23580,
#  23820,
#  23900,
#  24030,
#  25130,
#  25420,
#  25480,
#  25780,
#  26860,
#  28230,
#  28340,
#  29520,
#  29620,
#  29630,
#  29640,
#  29650,
#  29660,
#  29670,
#  29730,
#  29740,
#  30120,
#  30170,
#  32180,
#  32430,
#  34180,
#  34240,
#  34370,
#  34810,
#  34940,
#  35250,
#  37260,
#  37370,
#  37540,
#  37970,
#  38600,
#  38610,
#  39110,
#  39200,
#  39360,
#  39630,
#  41100,
#  41340,
#  42420,
#  44330,
#  44680,
#  44690,
#  44970,
#  46790,
#  47130,
#  47780,
#  48050]

# %%
pd.DataFrame.from_dict(df_name_landmarks).to_csv('data/landmarks_name_markup.csv')
pd.DataFrame.from_dict(df_description_landmarks).to_csv('data/landmarks_description_markup.csv')

# %%
df_cities = df.drop(['description','description_grok'], axis=1)
df_cities['description'] = df_cities['city_ascii']
df_cities.to_csv('data/cities_markup.csv')
df_cities
# Out:
#                    city        city_ascii      lat       lng  \
# 0                 Tokyo             Tokyo  35.6870  139.7495
# 1               Jakarta           Jakarta  -6.1750  106.8275
# 2                 Delhi             Delhi  28.6100   77.2300
# 3             Guangzhou         Guangzhou  23.1300  113.2600
# 4                Mumbai            Mumbai  19.0761   72.8775
# ...                 ...               ...      ...       ...
# 48054          Al Jabīn          Al Jabin  14.7040   43.5990
# 48055         Nelspruit         Nelspruit -25.4745   30.9703
# 48056          Gqeberha          Gqeberha -33.9681   25.5981
# 48057            Lupane            Lupane -18.9315   27.8070
# 48058  Charlotte Amalie  Charlotte Amalie  18.3420  -64.9331
#
#                    country iso2 iso3          admin_name  capital  population  \
# 0                    Japan   JP  JPN               Tōkyō  primary  37785000.0
# 1                Indonesia   ID  IDN             Jakarta  primary  33756000.0
# 2                    India   IN  IND               Delhi    admin  32226000.0
# 3                    China   CN  CHN           Guangdong    admin  26940000.0
# 4                    India   IN  IND         Mahārāshtra    admin  24973000.0
# ...                    ...  ...  ...                 ...      ...         ...
# 48054                Yemen   YE  YEM              Raymah    admin         NaN
# 48055         South Africa   ZA  ZAF          Mpumalanga    admin         NaN
# 48056         South Africa   ZA  ZAF        Eastern Cape      NaN         NaN
# 48057             Zimbabwe   ZW  ZWE  Matabeleland North    admin         NaN
# 48058  U.S. Virgin Islands   VI  VIR      Virgin Islands  primary         NaN
#
#                id       description
# 0      1392685764             Tokyo
# 1      1360771077           Jakarta
# 2      1356872604             Delhi
# 3      1156237133         Guangzhou
# 4      1356226629            Mumbai
# ...           ...               ...
# 48054  1887910100          Al Jabin
# 48055  1710114438         Nelspruit
# 48056  1710000082          Gqeberha
# 48057  1716206606            Lupane
# 48058  1850037473  Charlotte Amalie
#
# [48059 rows x 12 columns]

# %%
async def ask_gpt_geographic(client, data, model = "gpt-4.1"):
    try:
        city_list = "; ".join([f"{name}, {latitude}, {longitude}" for name, latitude, longitude in data])
        response = await client.chat.completions.create(
            model=model,
            messages=[
                {"role": "system", "content": f"You are creating riddles. If you get the name of city/town/village, you try to describe it without naming it or its coordinates. \
                    Use nearest geographic places to describe settlement. Never name the city/town/village.\
                    Use hints that distinguish the place described from other similar places in the world. Your description contains only a couple sentences. Use only english language in answer." },
                {"role": "user", "content": f"You will get a list of names,latitude,longitude of {len(list(data))} cities/towns/villages in <list> tokens, you should answer to them separately, separate them by <answer> token. <list>{city_list}<list>"}
            ]
        )
        return response.choices[0].message.content
    except Exception as e:
        return f"Ошибка: {str(e)}"

# %%
batch = 10
tasks = pulemet.process([ask_gpt_geographic(client, zip(df[i:i+batch]['city_ascii'].values, df[i:i+batch]['lat'].values, df[i:i+batch]['lng'].values)) for i in range(0, len(df), batch)])
responses_geograpic = await asyncio.gather(*tasks, return_exceptions=True)
# Out:
# Total: 100%|██████████| 4811/4811 [41:49<00:00,  1.99it/s]

# %%
failed = []
responses_fixed = []
for i in range(0, len(df), batch):
    if len(('<answer>'+responses_geograpic[i//batch]+'<answer>').replace('\n', '').replace('<answer><answer>', '<answer>').replace('<answer><answer>', '<answer>').split('<answer>')[1:-1]) != batch:
        responses_fixed.extend(['']*min(batch, len(df)-i))
        failed.append(i)
    else:
        responses_fixed.extend(('<answer>'+responses_geograpic[i//batch]+'<answer>').replace('\n', '').replace('<answer><answer>', '<answer>').replace('<answer><answer>', '<answer>').split('<answer>')[1:-1])
failed
# Out:
# [19490, 19580, 19810, 19860, 24010, 36660, 48050]

# %%
df['description']= responses_fixed
df[df['description']!=''].to_csv('data/gpt41_geographic_markup.csv')
df.head(20)
# Out:
#             city    city_ascii      lat       lng        country iso2 iso3  \
# 0          Tokyo         Tokyo  35.6870  139.7495          Japan   JP  JPN
# 1        Jakarta       Jakarta  -6.1750  106.8275      Indonesia   ID  IDN
# 2          Delhi         Delhi  28.6100   77.2300          India   IN  IND
# 3      Guangzhou     Guangzhou  23.1300  113.2600          China   CN  CHN
# 4         Mumbai        Mumbai  19.0761   72.8775          India   IN  IND
# 5         Manila        Manila  14.5958  120.9772    Philippines   PH  PHL
# 6       Shanghai      Shanghai  31.2286  121.4747          China   CN  CHN
# 7      São Paulo     Sao Paulo -23.5504  -46.6339         Brazil   BR  BRA
# 8          Seoul         Seoul  37.5667  126.9833   Korea, South   KR  KOR
# 9    Mexico City   Mexico City  19.4333  -99.1333         Mexico   MX  MEX
# 10       Kolkāta       Kolkata  22.5675   88.3700          India   IN  IND
# 11         Cairo         Cairo  30.0444   31.2358          Egypt   EG  EGY
# 12       Karachi       Karachi  24.8600   67.0100       Pakistan   PK  PAK
# 13         Dhaka         Dhaka  23.7289   90.3944     Bangladesh   BD  BGD
# 14      New York      New York  40.6943  -73.9249  United States   US  USA
# 15       Beijing       Beijing  39.9067  116.3975          China   CN  CHN
# 16       Bangkok       Bangkok  13.7525  100.4942       Thailand   TH  THA
# 17      Shenzhen      Shenzhen  22.5415  114.0596          China   CN  CHN
# 18        Moscow        Moscow  55.7506   37.6175         Russia   RU  RUS
# 19  Buenos Aires  Buenos Aires -34.6036  -58.3814      Argentina   AR  ARG
#
#                           admin_name  capital  population          id  \
# 0                              Tōkyō  primary  37785000.0  1392685764
# 1                            Jakarta  primary  33756000.0  1360771077
# 2                              Delhi    admin  32226000.0  1356872604
# 3                          Guangdong    admin  26940000.0  1156237133
# 4                        Mahārāshtra    admin  24973000.0  1356226629
# 5                             Manila  primary  24922000.0  1608618140
# 6                           Shanghai    admin  24073000.0  1156073548
# 7                          São Paulo    admin  23086000.0  1076532519
# 8                              Seoul  primary  23016000.0  1410836482
# 9                   Ciudad de México  primary  21804000.0  1484247881
# 10                       West Bengal    admin  21747000.0  1356060520
# 11                        Al Qāhirah  primary  20296000.0  1818253931
# 12                             Sindh    admin  20249000.0  1586129469
# 13                             Dhaka  primary  19134000.0  1050529279
# 14                          New York      NaN  18832416.0  1840034016
# 15                           Beijing  primary  18522000.0  1156228865
# 16            Krung Thep Maha Nakhon  primary  18007000.0  1764068610
# 17                         Guangdong    minor  17619000.0  1156158707
# 18                            Moskva  primary  17332000.0  1643318494
# 19  Buenos Aires, Ciudad Autónoma de  primary  16710000.0  1032717330
#
#                                           description
# 0   This sprawling metropolis lies on the eastern ...
# 1   Situated just south of the equator on the isla...
# 2   Resting along the banks of the Yamuna River, t...
# 3   Found on the Pearl River delta, this city is l...
# 4   Located on the west coast of a peninsular nati...
# 5   This densely populated capital sits on the isl...
# 6   Positioned on the east coast at the mouth of t...
# 7   Nestled on a plateau inland from the Atlantic ...
# 8   Not far from the border with North Korea, this...
# 9   Resting in a high valley in central Mexico, th...
# 10  This teeming metropolis stands on the banks of...
# 11  This ancient city spreads along the life-givin...
# 12  This port city guards the Arabian Sea, southwe...
# 13  This mega-city sits on the Buriganga River, no...
# 14  This global giant stretches between the mouth ...
# 15  This immense capital lies just northwest of Ti...
# 16  This vibrant city squats on the delta of the C...
# 17  This glowing metropolis sits just above Hong K...
# 18  This vast expanse blankets the banks of the Mo...
# 19  This southern metropolis kisses the edge of th...

# %%
async def ask_gpt_facts(client, data, model = "gpt-4.1-nano"):
    try:
        city_list = "; ".join([f"{name}, {latitude}, {longitude}" for name, latitude, longitude in data])
        response = await client.chat.completions.create(
            model=model,
            messages=[
                {"role": "system", "content": f"You are creating short historical article. If you get the name of city/town/village, you try to describe it without naming it or its coordinates. \
                    Use historical facts or interesting facts to describe settlement. Never name the city/town/village.\
                    Use hints that distinguish the place described from other similar places in the world. Your description contains only a couple sentences. Use only english language in answer." },
                {"role": "user", "content": f"You will get a list of names,latitude,longitude of {len(list(data))} cities/towns/villages in <list> tokens, you should answer to them separately, separate them by <answer> token. <list>{city_list}<list>"}
            ]
        )
        return response.choices[0].message.content
    except Exception as e:
        return f"Ошибка: {str(e)}"

# %%
batch = 10
tasks = pulemet.process([ask_gpt_facts(client, zip(df[i:i+batch]['city_ascii'].values, df[i:i+batch]['lat'].values, df[i:i+batch]['lng'].values)) for i in range(0, len(df), batch)])
responses_facts = await asyncio.gather(*tasks, return_exceptions=True)
# Out:
# Total: 100%|██████████| 9617/9617 [1:22:38<00:00,  2.00it/s]

# %%
failed = []
responses_fixed = []
for i in range(0, len(df), batch):
    if len(('<answer>'+responses_facts[i//batch]+'<answer>').replace('\n', '').replace('<answer><answer>', '<answer>').replace('<answer><answer>', '<answer>').split('<answer>')[1:-1]) != batch:
        responses_fixed.extend(['']*min(batch, len(df)-i))
        failed.append(i)
    else:
        responses_fixed.extend(('<answer>'+responses_facts[i//batch]+'<answer>').replace('\n', '').replace('<answer><answer>', '<answer>').replace('<answer><answer>', '<answer>').split('<answer>')[1:-1])
failed
# Out:
# [160,
#  300,
#  460,
#  570,
#  610,
#  720,
#  960,
#  1030,
#  1190,
#  1200,
#  1280,
#  1370,
#  1540,
#  1570,
#  1720,
#  1750,
#  1790,
#  1880,
#  1890,
#  2030,
#  2320,
#  2450,
#  2460,
#  2550,
#  2640,
#  2830,
#  3110,
#  3230,
#  3240,
#  3280,
#  3340,
#  3390,
#  3400,
#  3420,
#  3500,
#  3630,
#  3650,
#  3820,
#  3870,
#  4000,
#  4050,
#  4140,
#  4200,
#  4470,
#  4670,
#  4760,
#  5140,
#  5190,
#  5310,
#  5340,
#  5380,
#  5450,
#  5610,
#  5620,
#  5690,
#  6000,
#  6250,
#  6380,
#  6410,
#  6550,
#  6620,
#  6740,
#  6810,
#  6850,
#  6870,
#  7020,
#  7050,
#  7090,
#  7160,
#  7180,
#  7410,
#  7440,
#  7560,
#  7740,
#  7950,
#  7990,
#  8050,
#  8190,
#  8240,
#  8410,
#  8480,
#  8520,
#  8570,
#  8600,
#  8770,
#  8860,
#  8930,
#  8960,
#  9020,
#  9170,
#  9260,
#  9280,
#  9360,
#  9570,
#  9610,
#  9690,
#  9800,
#  9870,
#  9880,
#  9930,
#  10310,
#  10480,
#  10560,
#  10640,
#  10720,
#  10860,
#  10920,
#  11040,
#  11060,
#  11250,
#  11390,
#  11430,
#  11470,
#  11740,
#  11770,
#  11800,
#  11870,
#  11920,
#  12000,
#  12080,
#  12220,
#  12310,
#  12420,
#  12590,
#  12730,
#  12760,
#  12790,
#  12820,
#  12860,
#  13000,
#  13030,
#  13040,
#  13060,
#  13120,
#  13560,
#  13620,
#  13640,
#  13700,
#  13710,
#  13860,
#  13900,
#  13920,
#  13960,
#  14320,
#  14470,
#  14680,
#  14720,
#  14750,
#  14800,
#  14860,
#  15030,
#  15070,
#  15320,
#  15340,
#  15440,
#  15460,
#  15480,
#  15650,
#  15750,
#  15820,
#  15880,
#  15930,
#  15960,
#  15980,
#  16220,
#  16300,
#  16330,
#  16380,
#  16470,
#  16530,
#  16550,
#  16600,
#  16650,
#  16770,
#  16850,
#  16920,
#  16950,
#  16960,
#  16980,
#  17020,
#  17030,
#  17310,
#  17330,
#  17350,
#  17400,
#  17510,
#  17610,
#  17710,
#  17720,
#  17870,
#  17950,
#  18050,
#  18060,
#  18210,
#  18390,
#  18470,
#  18590,
#  18850,
#  18890,
#  18940,
#  19010,
#  19290,
#  19370,
#  19440,
#  19470,
#  19500,
#  19680,
#  19760,
#  19920,
#  20060,
#  20310,
#  20320,
#  20330,
#  20360,
#  20610,
#  20640,
#  20670,
#  20750,
#  20850,
#  21190,
#  21240,
#  21330,
#  21360,
#  21400,
#  21410,
#  21470,
#  21510,
#  21570,
#  22000,
#  22050,
#  22110,
#  22230,
#  22280,
#  22320,
#  22400,
#  22440,
#  22550,
#  22580,
#  22630,
#  22690,
#  22850,
#  22910,
#  23100,
#  23140,
#  23230,
#  23470,
#  23560,
#  23790,
#  23800,
#  23810,
#  23830,
#  23850,
#  23870,
#  23980,
#  24010,
#  24050,
#  24270,
#  24320,
#  24350,
#  24380,
#  24540,
#  24710,
#  24740,
#  24770,
#  24780,
#  24870,
#  24990,
#  25000,
#  25070,
#  25150,
#  25170,
#  25250,
#  25330,
#  25370,
#  25440,
#  25450,
#  25540,
#  25680,
#  25700,
#  25760,
#  25780,
#  25810,
#  25900,
#  25910,
#  25950,
#  26060,
#  26080,
#  26110,
#  26350,
#  26400,
#  26480,
#  26750,
#  26760,
#  26840,
#  26870,
#  26990,
#  27000,
#  27010,
#  27130,
#  27450,
#  27460,
#  27540,
#  27630,
#  27760,
#  27770,
#  27790,
#  27920,
#  27940,
#  27960,
#  28020,
#  28030,
#  28060,
#  28110,
#  28130,
#  28190,
#  28270,
#  28330,
#  28380,
#  28400,
#  28600,
#  28720,
#  28990,
#  29120,
#  29350,
#  29380,
#  29410,
#  29480,
#  29630,
#  29680,
#  29700,
#  29730,
#  29810,
#  30070,
#  30120,
#  30500,
#  30640,
#  30670,
#  30740,
#  30790,
#  30950,
#  31020,
#  31050,
#  31070,
#  31290,
#  31360,
#  31430,
#  31470,
#  31500,
#  31550,
#  31580,
#  31590,
#  31680,
#  31790,
#  31850,
#  31910,
#  31930,
#  31970,
#  32300,
#  32420,
#  32460,
#  32880,
#  33040,
#  33110,
#  33130,
#  33230,
#  33310,
#  33380,
#  33480,
#  33490,
#  33580,
#  33830,
#  33990,
#  34050,
#  34110,
#  34140,
#  34160,
#  34300,
#  34500,
#  34530,
#  34560,
#  34590,
#  34620,
#  34660,
#  34730,
#  34800,
#  34850,
#  34930,
#  34940,
#  34950,
#  34960,
#  34970,
#  35350,
#  35520,
#  35690,
#  35700,
#  35740,
#  35780,
#  35830,
#  35850,
#  35950,
#  35960,
#  36030,
#  36090,
#  36100,
#  36250,
#  36290,
#  36540,
#  36590,
#  36600,
#  36660,
#  36820,
#  36850,
#  36980,
#  37010,
#  37090,
#  37220,
#  37340,
#  37560,
#  37600,
#  37670,
#  37750,
#  37760,
#  37800,
#  37910,
#  37980,
#  38000,
#  38040,
#  38080,
#  38100,
#  38120,
#  38250,
#  38400,
#  38440,
#  38490,
#  38500,
#  38620,
#  38640,
#  38760,
#  38810,
#  38820,
#  38920,
#  39070,
#  39080,
#  39250,
#  39390,
#  39550,
#  39610,
#  39660,
#  39690,
#  39730,
#  39800,
#  39820,
#  39890,
#  39990,
#  40030,
#  40090,
#  40110,
#  40230,
#  40240,
#  40540,
#  40780,
#  40860,
#  40900,
#  40980,
#  41160,
#  41200,
#  41210,
#  41460,
#  41520,
#  41550,
#  41570,
#  41600,
#  41720,
#  41830,
#  41860,
#  42140,
#  42300,
#  42490,
#  42500,
#  42580,
#  42730,
#  42780,
#  43120,
#  43130,
#  43300,
#  43310,
#  43320,
#  43370,
#  43630,
#  43680,
#  43930,
#  43970,
#  44240,
#  44500,
#  44580,
#  44660,
#  44690,
#  44700,
#  44720,
#  44740,
#  44890,
#  44960,
#  44970,
#  45090,
#  45100,
#  45110,
#  45140,
#  45230,
#  45250,
#  45260,
#  45320,
#  45420,
#  45570,
#  45750,
#  45830,
#  45840,
#  45910,
#  45940,
#  46010,
#  46040,
#  46060,
#  46170,
#  46290,
#  46320,
#  46430,
#  46480,
#  46490,
#  46620,
#  46630,
#  46670,
#  46710,
#  46820,
#  47020,
#  47250,
#  47430,
#  47450,
#  47460,
#  47550,
#  47590,
#  47710,
#  47720,
#  47740,
#  47760,
#  47840,
#  47930,
#  47970,
#  48050]

# %%
df['description']= responses_fixed
df[df['description']!=''].to_csv('data/gpt41nano_facts_markup.csv')
df.head(20)
# Out:
#             city    city_ascii      lat       lng        country iso2 iso3  \
# 0          Tokyo         Tokyo  35.6870  139.7495          Japan   JP  JPN
# 1        Jakarta       Jakarta  -6.1750  106.8275      Indonesia   ID  IDN
# 2          Delhi         Delhi  28.6100   77.2300          India   IN  IND
# 3      Guangzhou     Guangzhou  23.1300  113.2600          China   CN  CHN
# 4         Mumbai        Mumbai  19.0761   72.8775          India   IN  IND
# 5         Manila        Manila  14.5958  120.9772    Philippines   PH  PHL
# 6       Shanghai      Shanghai  31.2286  121.4747          China   CN  CHN
# 7      São Paulo     Sao Paulo -23.5504  -46.6339         Brazil   BR  BRA
# 8          Seoul         Seoul  37.5667  126.9833   Korea, South   KR  KOR
# 9    Mexico City   Mexico City  19.4333  -99.1333         Mexico   MX  MEX
# 10       Kolkāta       Kolkata  22.5675   88.3700          India   IN  IND
# 11         Cairo         Cairo  30.0444   31.2358          Egypt   EG  EGY
# 12       Karachi       Karachi  24.8600   67.0100       Pakistan   PK  PAK
# 13         Dhaka         Dhaka  23.7289   90.3944     Bangladesh   BD  BGD
# 14      New York      New York  40.6943  -73.9249  United States   US  USA
# 15       Beijing       Beijing  39.9067  116.3975          China   CN  CHN
# 16       Bangkok       Bangkok  13.7525  100.4942       Thailand   TH  THA
# 17      Shenzhen      Shenzhen  22.5415  114.0596          China   CN  CHN
# 18        Moscow        Moscow  55.7506   37.6175         Russia   RU  RUS
# 19  Buenos Aires  Buenos Aires -34.6036  -58.3814      Argentina   AR  ARG
#
#                           admin_name  capital  population          id  \
# 0                              Tōkyō  primary  37785000.0  1392685764
# 1                            Jakarta  primary  33756000.0  1360771077
# 2                              Delhi    admin  32226000.0  1356872604
# 3                          Guangdong    admin  26940000.0  1156237133
# 4                        Mahārāshtra    admin  24973000.0  1356226629
# 5                             Manila  primary  24922000.0  1608618140
# 6                           Shanghai    admin  24073000.0  1156073548
# 7                          São Paulo    admin  23086000.0  1076532519
# 8                              Seoul  primary  23016000.0  1410836482
# 9                   Ciudad de México  primary  21804000.0  1484247881
# 10                       West Bengal    admin  21747000.0  1356060520
# 11                        Al Qāhirah  primary  20296000.0  1818253931
# 12                             Sindh    admin  20249000.0  1586129469
# 13                             Dhaka  primary  19134000.0  1050529279
# 14                          New York      NaN  18832416.0  1840034016
# 15                           Beijing  primary  18522000.0  1156228865
# 16            Krung Thep Maha Nakhon  primary  18007000.0  1764068610
# 17                         Guangdong    minor  17619000.0  1156158707
# 18                            Moskva  primary  17332000.0  1643318494
# 19  Buenos Aires, Ciudad Autónoma de  primary  16710000.0  1032717330
#
#                                           description
# 0   This metropolis is renowned for its towering m...
# 1   This capital city is situated along a major ri...
# 2   As the capital of a vast northern plain, this ...
# 3   This south Chinese city, once a major trading ...
# 4   This coastal city is India's financial capital...
# 5   This insular city, located on an archipelago i...
# 6   This global financial hub on China's eastern c...
# 7   Located on a high-altitude plateau, this South...
# 8   This mainly Seoul-based metropolis is a histor...
# 9   This historic city, situated in the heart of a...
# 10   This vibrant metropolis was once the capital ...
# 11   This ancient city is famed for its sprawling ...
# 12   This major port city is known as a key gatewa...
# 13   This city is the capital of a nation that exp...
# 14   This sprawling urban settlement sits at the m...
# 15   This ancient capital is renowned for its hist...
# 16   This well-known metropolis is situated along ...
# 17   This coastal city mainly developed as a Speci...
# 18   This city is the political and cultural heart...
# 19   This southern city is famed for its vibrant t...

# %%
async def ask_deepseek(client, data, model = "deepseek-r1"):
    try:
        city_list = "; ".join([f"{name}, {latitude}, {longitude}" for name, latitude, longitude in data])
        response = await client.chat.completions.create(
            model=model,
            messages=[
                {"role": "system", "content": f"You are creating preview of article in journal. If you get the name of city/town/village, you try to describe it without naming it or its coordinates. \
                    Use nearest geographic objects or famous landmarks to describe settlement. Use simple phases. Never name the city/town/village.\
                    Use hints that distinguish the place described from other similar places in the world. Your description contains only a couple sentences. Use only english language in answer." },
                {"role": "user", "content": f"You will get a list of names,latitude,longitude of {len(list(data))} cities/towns/villages in <list> tokens, you should answer to them separately, separate them by <answer> token. <list>{city_list}<list>"}
            ]
        )
        return response.choices[0].message.content
    except Exception as e:
        return f"Ошибка: {str(e)}"

# %%
batch = 10
tasks = pulemet.process([ask_deepseek(client, zip(df[i:i+batch]['city_ascii'].values, df[i:i+batch]['lat'].values, df[i:i+batch]['lng'].values)) for i in range(0, len(df), batch)])
responses_deepseek = await asyncio.gather(*tasks, return_exceptions=True)
# Out:
# Total: 100%|██████████| 14433/14433 [5:24:36<00:00,  1.18s/it]

# %%
failed = []
responses_fixed = []
for i in range(0, len(df), batch):
    if len(('<answer>'+responses_deepseek[i//batch]+'<answer>').replace('\n', '').replace('<answer><answer>', '<answer>').replace('<answer><answer>', '<answer>').split('<answer>')[1:-1]) != batch:
        responses_fixed.extend(['']*min(batch, len(df)-i))
        failed.append(i)
    else:
        responses_fixed.extend(('<answer>'+responses_deepseek[i//batch].replace('</answer>', '')+'<answer>').replace('\n', '').replace('<answer><answer>', '<answer>').replace('<answer><answer>', '<answer>').split('<answer>')[1:-1])
failed
# Out:
# [1300,
#  1540,
#  3070,
#  3110,
#  3230,
#  3440,
#  3450,
#  3490,
#  3500,
#  3550,
#  3560,
#  3570,
#  3580,
#  3600,
#  3670,
#  3690,
#  3710,
#  3720,
#  3860,
#  4100,
#  5610,
#  7070,
#  7510,
#  8140,
#  8410,
#  9130,
#  9160,
#  9180,
#  9240,
#  9380,
#  9420,
#  10730,
#  11460,
#  11470,
#  11560,
#  11580,
#  11590,
#  11640,
#  11650,
#  12450,
#  16620,
#  18420,
#  20020,
#  20180,
#  23790,
#  24430,
#  24780,
#  29870,
#  30050,
#  30100,
#  31350,
#  32140,
#  37460,
#  38520,
#  39320,
#  39520,
#  40200,
#  41050,
#  41610,
#  43290,
#  44330,
#  46680,
#  48050]

# %%
df['description']= responses_fixed
df[df['description']!=''].to_csv('data/deepseekr1_markup.csv')
df.head(20)
# Out:
#             city    city_ascii      lat       lng        country iso2 iso3  \
# 0          Tokyo         Tokyo  35.6870  139.7495          Japan   JP  JPN
# 1        Jakarta       Jakarta  -6.1750  106.8275      Indonesia   ID  IDN
# 2          Delhi         Delhi  28.6100   77.2300          India   IN  IND
# 3      Guangzhou     Guangzhou  23.1300  113.2600          China   CN  CHN
# 4         Mumbai        Mumbai  19.0761   72.8775          India   IN  IND
# 5         Manila        Manila  14.5958  120.9772    Philippines   PH  PHL
# 6       Shanghai      Shanghai  31.2286  121.4747          China   CN  CHN
# 7      São Paulo     Sao Paulo -23.5504  -46.6339         Brazil   BR  BRA
# 8          Seoul         Seoul  37.5667  126.9833   Korea, South   KR  KOR
# 9    Mexico City   Mexico City  19.4333  -99.1333         Mexico   MX  MEX
# 10       Kolkāta       Kolkata  22.5675   88.3700          India   IN  IND
# 11         Cairo         Cairo  30.0444   31.2358          Egypt   EG  EGY
# 12       Karachi       Karachi  24.8600   67.0100       Pakistan   PK  PAK
# 13         Dhaka         Dhaka  23.7289   90.3944     Bangladesh   BD  BGD
# 14      New York      New York  40.6943  -73.9249  United States   US  USA
# 15       Beijing       Beijing  39.9067  116.3975          China   CN  CHN
# 16       Bangkok       Bangkok  13.7525  100.4942       Thailand   TH  THA
# 17      Shenzhen      Shenzhen  22.5415  114.0596          China   CN  CHN
# 18        Moscow        Moscow  55.7506   37.6175         Russia   RU  RUS
# 19  Buenos Aires  Buenos Aires -34.6036  -58.3814      Argentina   AR  ARG
#
#                           admin_name  capital  population          id  \
# 0                              Tōkyō  primary  37785000.0  1392685764
# 1                            Jakarta  primary  33756000.0  1360771077
# 2                              Delhi    admin  32226000.0  1356872604
# 3                          Guangdong    admin  26940000.0  1156237133
# 4                        Mahārāshtra    admin  24973000.0  1356226629
# 5                             Manila  primary  24922000.0  1608618140
# 6                           Shanghai    admin  24073000.0  1156073548
# 7                          São Paulo    admin  23086000.0  1076532519
# 8                              Seoul  primary  23016000.0  1410836482
# 9                   Ciudad de México  primary  21804000.0  1484247881
# 10                       West Bengal    admin  21747000.0  1356060520
# 11                        Al Qāhirah  primary  20296000.0  1818253931
# 12                             Sindh    admin  20249000.0  1586129469
# 13                             Dhaka  primary  19134000.0  1050529279
# 14                          New York      NaN  18832416.0  1840034016
# 15                           Beijing  primary  18522000.0  1156228865
# 16            Krung Thep Maha Nakhon  primary  18007000.0  1764068610
# 17                         Guangdong    minor  17619000.0  1156158707
# 18                            Moskva  primary  17332000.0  1643318494
# 19  Buenos Aires, Ciudad Autónoma de  primary  16710000.0  1032717330
#
#                                           description
# 0   A metropolis near a snow-capped stratovolcano ...
# 1   A coastal capital flanked by a strait notoriou...
# 2   Built along a sacred river, this city lies clo...
# 3   Positioned in a fertile delta where a major ri...
# 4   A peninsula city facing an ancient maritime tr...
# 5   Overlooking a natural harbor and a bay once ra...
# 6   At the estuary of a continent’s longest river,...
# 7   Nestled below a mountain range draped in Atlan...
# 8   Encircled by fortress walls and bisected by a ...
# 9   Set in a highland basin surrounded by active v...
# 10  A bustling metropolis straddling a major distr...
# 11  Nestled along the Nile’s delta, this ancient h...
# 12  Perched on the Arabian Sea’s edge, this port c...
# 13  Sprawling along a winding river near the Bay o...
# 14  An island-linked global financial center flank...
# 15  Encircled by arid northern plains, this imperi...
# 16  Laced with canals and temples, this low-lying ...
# 17  A tech boomtown bordering a former British col...
# 18  Bisected by a winding river, this frosty capit...
# 19  Perched on the Rio de la Plata’s western bank,...

# %%
async def ask_deepseek_geographic(client, data, model = "deepseek-r1"):
    try:
        city_list = "; ".join([f"{name}, {latitude}, {longitude}" for name, latitude, longitude in data])
        response = await client.chat.completions.create(
            model=model,
            messages=[
                {"role": "system", "content": f"You are helping to find settlement on the map. If you get the name of city/town/village, you try to describe it without naming it or its coordinates. \
                    Use only nearest natural geographic objects and name them to describe settlement. Use simple phases. Never name the city/town/village.\
                    Use hints that distinguish the place described from other similar places in the world. Your description contains only a couple sentences. Use only english language in answer." },
                {"role": "user", "content": f"You will get a list of names,latitude,longitude of {len(list(data))} cities/towns/villages in <list> tokens, you should answer to them separately, separate them by <answer> token. <list>{city_list}<list>"}
            ]
        )
        return response.choices[0].message.content
    except Exception as e:
        return f"Ошибка: {str(e)}"

# %%
batch = 10
tasks = pulemet.process([ask_deepseek_geographic(client, zip(df[i:i+batch]['city_ascii'].values, df[i:i+batch]['lat'].values, df[i:i+batch]['lng'].values)) for i in range(0, len(df), batch)])
responses_deepseek_geographic = await asyncio.gather(*tasks, return_exceptions=True)
# Out:
# Total: 100%|██████████| 19239/19239 [6:51:16<00:00,  1.37s/it]

# %%
failed = []
responses_fixed = []
for i in range(0, len(df), batch):
    if len(('<answer>'+responses_deepseek_geographic[i//batch].replace('</answer>', '')+'<answer>').replace('\n', '').replace('<answer><answer>', '<answer>').replace('<answer><answer>', '<answer>').split('<answer>')[1:-1]) != batch:
        responses_fixed.extend(['']*min(batch, len(df)-i))
        failed.append(i)
    else:
        responses_fixed.extend(('<answer>'+responses_deepseek_geographic[i//batch].replace('</answer>', '')+'<answer>').replace('\n', '').replace('<answer><answer>', '<answer>').replace('<answer><answer>', '<answer>').split('<answer>')[1:-1])
failed
# Out:
# [1780,
#  4260,
#  5990,
#  10340,
#  10830,
#  12560,
#  14990,
#  15010,
#  15100,
#  15110,
#  18940,
#  20410,
#  21740,
#  26540,
#  26820,
#  29190,
#  31730,
#  31790,
#  31810,
#  37690,
#  46150,
#  48050]

# %%
df['description']= responses_fixed
df[df['description']!=''].to_csv('data/deepseekr1_geographic_markup.csv')
df.head(20)
# Out:
#             city    city_ascii      lat       lng        country iso2 iso3  \
# 0          Tokyo         Tokyo  35.6870  139.7495          Japan   JP  JPN
# 1        Jakarta       Jakarta  -6.1750  106.8275      Indonesia   ID  IDN
# 2          Delhi         Delhi  28.6100   77.2300          India   IN  IND
# 3      Guangzhou     Guangzhou  23.1300  113.2600          China   CN  CHN
# 4         Mumbai        Mumbai  19.0761   72.8775          India   IN  IND
# 5         Manila        Manila  14.5958  120.9772    Philippines   PH  PHL
# 6       Shanghai      Shanghai  31.2286  121.4747          China   CN  CHN
# 7      São Paulo     Sao Paulo -23.5504  -46.6339         Brazil   BR  BRA
# 8          Seoul         Seoul  37.5667  126.9833   Korea, South   KR  KOR
# 9    Mexico City   Mexico City  19.4333  -99.1333         Mexico   MX  MEX
# 10       Kolkāta       Kolkata  22.5675   88.3700          India   IN  IND
# 11         Cairo         Cairo  30.0444   31.2358          Egypt   EG  EGY
# 12       Karachi       Karachi  24.8600   67.0100       Pakistan   PK  PAK
# 13         Dhaka         Dhaka  23.7289   90.3944     Bangladesh   BD  BGD
# 14      New York      New York  40.6943  -73.9249  United States   US  USA
# 15       Beijing       Beijing  39.9067  116.3975          China   CN  CHN
# 16       Bangkok       Bangkok  13.7525  100.4942       Thailand   TH  THA
# 17      Shenzhen      Shenzhen  22.5415  114.0596          China   CN  CHN
# 18        Moscow        Moscow  55.7506   37.6175         Russia   RU  RUS
# 19  Buenos Aires  Buenos Aires -34.6036  -58.3814      Argentina   AR  ARG
#
#                           admin_name  capital  population          id  \
# 0                              Tōkyō  primary  37785000.0  1392685764
# 1                            Jakarta  primary  33756000.0  1360771077
# 2                              Delhi    admin  32226000.0  1356872604
# 3                          Guangdong    admin  26940000.0  1156237133
# 4                        Mahārāshtra    admin  24973000.0  1356226629
# 5                             Manila  primary  24922000.0  1608618140
# 6                           Shanghai    admin  24073000.0  1156073548
# 7                          São Paulo    admin  23086000.0  1076532519
# 8                              Seoul  primary  23016000.0  1410836482
# 9                   Ciudad de México  primary  21804000.0  1484247881
# 10                       West Bengal    admin  21747000.0  1356060520
# 11                        Al Qāhirah  primary  20296000.0  1818253931
# 12                             Sindh    admin  20249000.0  1586129469
# 13                             Dhaka  primary  19134000.0  1050529279
# 14                          New York      NaN  18832416.0  1840034016
# 15                           Beijing  primary  18522000.0  1156228865
# 16            Krung Thep Maha Nakhon  primary  18007000.0  1764068610
# 17                         Guangdong    minor  17619000.0  1156158707
# 18                            Moskva  primary  17332000.0  1643318494
# 19  Buenos Aires, Ciudad Autónoma de  primary  16710000.0  1032717330
#
#                                           description
# 0   A coastal metropolis near a volcanic peak, nes...
# 1   A tropical lowland port surrounded by dense ra...
# 2   A sprawling inland hub along a historic river,...
# 3   A delta city where a mighty river meets the se...
# 4   A peninsula settlement flanked by tidal creeks...
# 5   A bay-facing urban center straddling a river t...
# 6   A river-mouth megacity on alluvial plains, whe...
# 7   A highland plateau city near the escarpment of...
# 8   A river-valley capital surrounded by forested ...
# 9   A high-altitude basin settlement encircled by ...
# 10    A sprawling city along a major river's easte...
# 11    Nestled where a historic river splits into a...
# 12    Coastal metropolis bordering a turquoise sea...
# 13    Densely populated lowland where multiple riv...
# 14    Situated at the mouth of a long tidal estuar...
# 15    Ringed by arid mountains to the north and we...
# 16    Lies on a river delta near a tropical gulf, ...
# 17    Coastal city facing a narrow strait, backed ...
# 18    Sprawls across rolling plains along a windin...
# 19    Stretches along a wide, muddy estuary where ...

# %%
pd.concat([
    pd.read_csv('landmarks_name_markup.csv', index_col=0),
    pd.read_csv('landmarks_description_markup.csv', index_col=0),
    pd.read_csv('gpt41_markup.csv', index_col=0),
    pd.read_csv('grok_markup.csv', index_col=0),
    pd.read_csv('cities_markup.csv', index_col=0),
    pd.read_csv('gpt41_geographic_markup.csv', index_col=0),
    pd.read_csv('gpt41nano_facts_markup.csv', index_col=0),
    pd.read_csv('deepseekr1_markup.csv', index_col=0),
    pd.read_csv('deepseekr1_geographic_markup.csv', index_col=0),
    ]).to_csv('data/full_markup.csv')

# %%
async def ask_test_qwen(client, data, model = "qwen2.5-coder-32b-instruct"):
    try:
        city_list = "; ".join([f"{name}, {latitude}, {longitude}" for name, latitude, longitude in data])
        response = await client.chat.completions.create(
            model=model,
            messages=[
                {"role": "system", "content": f"You are creating riddles. If you get the name of city/town/village, you try to describe it without naming it or its coordinates. \
                    You usually use a description of the appearance of a city, famous facts about it, or the nearest iconic places. Never name the city/town/village.\
                    Use hints that distinguish the place described from other similar places in the world. Your description contains only a couple sentences. Use only english language in answer." },
                {"role": "user", "content": f"You will get a list of names,latitude,longitude of {len(list(data))} cities/towns/villages in <list> tokens, you should answer to them separately, separate them by <answer> token. <list>{city_list}<list>"}
            ]
        )
        return response.choices[0].message.content
    except Exception as e:
        return f"Ошибка: {str(e)}"

# %%
test_sample = df[:20000].sample(2000)
test_sample
# Out:
#               city   city_ascii      lat       lng            country iso2  \
# 9027     Brentwood    Brentwood  37.9356 -121.7190      United States   US
# 15237      Guacarí      Guacari   3.7667  -76.3333           Colombia   CO
# 3961     Zhanlicun    Zhanlicun  23.2881  116.2594              China   CN
# 7113         Arujá        Aruja -23.3967  -46.3211             Brazil   BR
# 7937   Novotroitsk  Novotroitsk  51.2039   58.3114             Russia   RU
# ...            ...          ...      ...       ...                ...  ...
# 538        Kharkiv      Kharkiv  49.9925   36.2311            Ukraine   UA
# 2673          Bata         Bata   1.8650    9.7700  Equatorial Guinea   GQ
# 10636    Bisceglie    Bisceglie  41.2409   16.5021              Italy   IT
# 1782       Nangong      Nangong  37.3590  115.4090              China   CN
# 332         Toluca       Toluca  19.2925  -99.6569             Mexico   MX
#
#       iso3             admin_name capital  population          id description
# 9027   USA             California     NaN     64609.0  1840018904
# 15237  COL        Valle del Cauca   minor     35513.0  1170383272
# 3961   CHN              Guangdong     NaN    161439.0  1156184947
# 7113   BRA              São Paulo   minor     83939.0  1076436872
# 7937   RUS  Orenburgskaya Oblast’   minor     74469.0  1643186193
# ...    ...                    ...     ...         ...         ...         ...
# 538    UKR      Kharkivska Oblast   admin   1421125.0  1804588111
# 2673   GNQ                Litoral   admin    250770.0  1226528087
# 10636  ITA                 Puglia     NaN     53534.0  1380547143
# 1782   CHN                  Hebei   minor    396718.0  1156426803
# 332    MEX                 México   admin   2476689.0  1484124846
#
# [2000 rows x 12 columns]

# %%
batch = 10
tasks = pulemet.process([ask_test_qwen(client, zip(test_sample[i:i+batch]['city_ascii'].values, test_sample[i:i+batch]['lat'].values, test_sample[i:i+batch]['lng'].values)) for i in range(0, len(test_sample), batch)])
responses_test = await asyncio.gather(*tasks, return_exceptions=True)
# Out:
# Total: 100%|██████████| 200/200 [03:57<00:00,  1.85it/s]

# %%
failed = []
responses_fixed = []
for i in range(0, len(test_sample), batch):
    if len(('<answer>'+responses_test[i//batch].replace('</answer>', '')+'<answer>').replace('\n', '').replace('<answer><answer>', '<answer>').replace('<answer><answer>', '<answer>').split('<answer>')[1:-1]) != batch:
        responses_fixed.extend(['']*min(batch, len(test_sample)-i))
        failed.append(i)
    else:
        responses_fixed.extend(('<answer>'+responses_test[i//batch].replace('</answer>', '')+'<answer>').replace('\n', '').replace('<answer><answer>', '<answer>').replace('<answer><answer>', '<answer>').split('<answer>')[1:-1])
failed
# Out:
# [140, 730, 1430, 1680]

# %%
test_sample['description']= responses_fixed
test_sample[test_sample['description']!=''].to_csv('data/test_markup.csv')
test_sample.head(20)
# Out:
#               city   city_ascii      lat       lng             country iso2  \
# 9027     Brentwood    Brentwood  37.9356 -121.7190       United States   US
# 15237      Guacarí      Guacari   3.7667  -76.3333            Colombia   CO
# 3961     Zhanlicun    Zhanlicun  23.2881  116.2594               China   CN
# 7113         Arujá        Aruja -23.3967  -46.3211              Brazil   BR
# 7937   Novotroitsk  Novotroitsk  51.2039   58.3114              Russia   RU
# 2629     Tokushima    Tokushima  34.0667  134.5500               Japan   JP
# 12387        Timbó        Timbo -26.8233  -49.2717              Brazil   BR
# 4858   Santo Tomas  Santo Tomas   7.5300  125.6200         Philippines   PH
# 4314        Jequié       Jequie -13.8578  -40.0839              Brazil   BR
# 4135        Andong       Andong  36.5592  128.7289        Korea, South   KR
# 11193       Susono       Susono  35.1739  138.9068               Japan   JP
# 5954    Santa Rosa   Santa Rosa -36.6167  -64.2833           Argentina   AR
# 18182     Hendījān     Hendijan  30.2383   49.7075                Iran   IR
# 11335        Janīn        Janin  32.4594   35.3009           West Bank   XW
# 9973         Kosai        Kosai  34.7184  137.5316               Japan   JP
# 13016      Yaguate      Yaguate  18.3300  -70.1800  Dominican Republic   DO
# 16075      Leticia      Leticia  -4.2167  -69.9333            Colombia   CO
# 17095  Haines City  Haines City  28.1102  -81.6157       United States   US
# 4432      Lichinga     Lichinga -13.3000   35.2456          Mozambique   MZ
# 9218      Visnagar     Visnagar  23.7000   72.5500               India   IN
#
#       iso3             admin_name capital  population          id  \
# 9027   USA             California     NaN     64609.0  1840018904
# 15237  COL        Valle del Cauca   minor     35513.0  1170383272
# 3961   CHN              Guangdong     NaN    161439.0  1156184947
# 7113   BRA              São Paulo   minor     83939.0  1076436872
# 7937   RUS  Orenburgskaya Oblast’   minor     74469.0  1643186193
# 2629   JPN              Tokushima   admin    254510.0  1392795984
# 12387  BRA         Santa Catarina   minor     44977.0  1076339334
# 4858   PHL        Davao del Norte     NaN    128667.0  1608792041
# 4314   BRA                  Bahia   minor    147202.0  1076558785
# 4135   KOR              Gyeongbuk   admin    153306.0  1410095935
# 11193  JPN               Shizuoka     NaN     50510.0  1392001986
# 5954   ARG               La Pampa   admin    102880.0  1032215828
# 18182  IRN              Khūzestān   minor     29015.0  1364511493
# 11335  XWB                    NaN     NaN     49908.0  1934524373
# 9973   JPN               Shizuoka     NaN     57682.0  1392881893
# 13016  DOM               Valdesia     NaN     42325.0  1214644367
# 16075  COL               Amazonas   admin     33503.0  1170548641
# 17095  USA                Florida     NaN     31156.0  1840014136
# 4432   MOZ                 Niassa   admin    142253.0  1508041628
# 9218   IND                Gujarāt     NaN     63073.0  1356690813
#
#                                              description
# 9027   A suburban area known for its affluent lifesty...
# 15237  Nestled in the lush Colombian Andes, this smal...
# 3961   Located in southern China, this village is kno...
# 7113   Situated in southeastern Brazil, this city is ...
# 7937   In the heart of Russia, this city is an import...
# 2629   This city on the island of Shikoku is renowned...
# 12387  Located in southern Brazil, this city is known...
# 4858   Nestled on the eastern coast of the Philippine...
# 4314   In the northeastern part of Brazil, this city ...
# 4135   Located in southeastern Korea, this city is kn...
# 11193  A city known for its Susono Grand Shrine, surr...
# 5954   A town nestled in Patagonia, famous for its vi...
# 18182  A village located near the Caspian Sea, known ...
# 11335  A town in Palestine with a rich history, inclu...
# 9973   A city in the Greater Tokyo Area, known for it...
# 13016  A small town on the island of Hispaniola, know...
# 16075  A city located at the confluence of the Japurá...
# 17095  A city in central Florida, known for its citru...
# 4432   A city in northern Mozambique, known for its P...
# 9218   A town in Gujarat, India, known for its cotton...
